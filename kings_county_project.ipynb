# %% [markdown]
# <img src=images/home2.jpg width = "1500" height = "4000">

# %% [markdown]
# ### Importing Libraries

# %%
import math
import numpy as np
import pandas as pd
import seaborn as sns
import statsmodels.api as sm
import matplotlib.pyplot as plt
from sklearn import metrics
from sklearn.metrics import r2_score
from statsmodels.formula.api import ols
from sklearn.dummy import DummyRegressor
from folium.plugins import FastMarkerCluster
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import OrdinalEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
# !ls Data
# Out:
# column_names.md   kc_house_data.csv

# %%
# Reading our csv file as dataframe
df = pd.read_csv('data/kc_house_data.csv')
df.head()
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014  221900.0         3       1.00         1180
# 1  6414100192   12/9/2014  538000.0         3       2.25         2570
# 2  5631500400   2/25/2015  180000.0         2       1.00          770
# 3  2487200875   12/9/2014  604000.0         4       3.00         1960
# 4  1954400510   2/18/2015  510000.0         3       2.00         1680
#
#    sqft_lot  floors waterfront  view  ...          grade sqft_above  \
# 0      5650     1.0        NaN  NONE  ...      7 Average       1180
# 1      7242     2.0         NO  NONE  ...      7 Average       2170
# 2     10000     1.0         NO  NONE  ...  6 Low Average        770
# 3      5000     1.0         NO  NONE  ...      7 Average       1050
# 4      8080     1.0         NO  NONE  ...         8 Good       1680
#
#    sqft_basement yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %%
df.tail(10)
# Out:
#                id        date      price  bedrooms  bathrooms  sqft_living  \
# 21587  7852140040   8/25/2014   507250.0         3       2.50         2270
# 21588  9834201367   1/26/2015   429000.0         3       2.00         1490
# 21589  3448900210  10/14/2014   610685.0         4       2.50         2520
# 21590  7936000429   3/26/2015  1010000.0         4       3.50         3510
# 21591  2997800021   2/19/2015   475000.0         3       2.50         1310
# 21592   263000018   5/21/2014   360000.0         3       2.50         1530
# 21593  6600060120   2/23/2015   400000.0         4       2.50         2310
# 21594  1523300141   6/23/2014   402101.0         2       0.75         1020
# 21595   291310100   1/16/2015   400000.0         3       2.50         1600
# 21596  1523300157  10/15/2014   325000.0         2       0.75         1020
#
#        sqft_lot  floors waterfront  view  ...      grade sqft_above  \
# 21587      5536     2.0        NaN  NONE  ...     8 Good       2270
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21597 entries, 0 to 21596
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21597 non-null  int64
#  1   date           21597 non-null  object
#  2   price          21597 non-null  float64
#  3   bedrooms       21597 non-null  int64
#  4   bathrooms      21597 non-null  float64
#  5   sqft_living    21597 non-null  int64
#  6   sqft_lot       21597 non-null  int64
#  7   floors         21597 non-null  float64
#  8   waterfront     19221 non-null  object
#  9   view           21534 non-null  object
#  10  condition      21597 non-null  object
#  11  grade          21597 non-null  object
#  12  sqft_above     21597 non-null  int64
#  13  sqft_basement  21597 non-null  object
#  14  yr_built       21597 non-null  int64
#  15  yr_renovated   17755 non-null  float64
#  16  zipcode        21597 non-null  int64
# ...

# %%
df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.159700e+04  2.159700e+04  21597.000000  21597.000000  21597.000000
# mean   4.580474e+09  5.402966e+05      3.373200      2.115826   2080.321850
# std    2.876736e+09  3.673681e+05      0.926299      0.768984    918.106125
# min    1.000102e+06  7.800000e+04      1.000000      0.500000    370.000000
# 25%    2.123049e+09  3.220000e+05      3.000000      1.750000   1430.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    sqft_above      yr_built  yr_renovated  \
# count  2.159700e+04  21597.000000  21597.000000  21597.000000  17755.000000
# mean   1.509941e+04      1.494096   1788.596842   1970.999676     83.636778
# ...

# %%
# We have a total of 6281 missing data in (waterfront 2376, view 63, and yr_renovated 3842) columns.
df.isna().sum().sum()
# Out:
# 6281

# %% [markdown]
# ## Data Preparation

# %%
#### Checking the distribution of our data.
df.hist(figsize = [15, 15],bins = 20)
plt.show()

# %%
# Checking for correlation in our data using heatmap.
df_corr = df.corr()
df_corr
# Out:
#                      id     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# id             1.000000 -0.016772  0.001150   0.005162    -0.012241 -0.131911
# price         -0.016772  1.000000  0.308787   0.525906     0.701917  0.089876
# bedrooms       0.001150  0.308787  1.000000   0.514508     0.578212  0.032471
# bathrooms      0.005162  0.525906  0.514508   1.000000     0.755758  0.088373
# sqft_living   -0.012241  0.701917  0.578212   0.755758     1.000000  0.173453
# sqft_lot      -0.131911  0.089876  0.032471   0.088373     0.173453  1.000000
# floors         0.018608  0.256804  0.177944   0.502582     0.353953 -0.004814
# sqft_above    -0.010799  0.605368  0.479386   0.686668     0.876448  0.184139
# yr_built       0.021617  0.053953  0.155670   0.507173     0.318152  0.052946
# yr_renovated  -0.012010  0.129599  0.018495   0.051050     0.055660  0.004513
# zipcode       -0.008211 -0.053402 -0.154092  -0.204786    -0.199802 -0.129586
# ...

# %%
plt.figure(figsize = (18, 10))
sns.heatmap(df_corr, center = 0, annot = True, cmap = 'RdYlGn')
plt.title('King Count Data Correlation Heatmap')
plt.show()

# %% [markdown]
# As showing above, we have some few collinearity in our data. And based on what's showing above we have more than 3 variables that have a strong linear relationship, meaning we have a special case of multicollinearity. Multicollinearity is a special case of collinearity where a strong linear relationship exists between 3 or more independent variables even if no pair of variables has a high correlation.

# %%
# Checking what columns have a strong relationship with price.
# And it seems like sqft_living, sqft_above, and sqft_living15 are the most correlated varibales in our data.
price_corr = df.corr()['price'].sort_values(ascending = False)
price_corr
# Out:
# price            1.000000
# sqft_living      0.701917
# sqft_above       0.605368
# sqft_living15    0.585241
# bathrooms        0.525906
# bedrooms         0.308787
# lat              0.306692
# floors           0.256804
# yr_renovated     0.129599
# sqft_lot         0.089876
# sqft_lot15       0.082845
# yr_built         0.053953
# long             0.022036
# id              -0.016772
# zipcode         -0.053402
# Name: price, dtype: float64

# %% [markdown]
# ## Dealing with missing data.

# %%
# Checking numerical columns. 
df_numeric = df.select_dtypes(include=['int64', 'float64'])

df_non_numeric = df.select_dtypes(exclude=['int64', 'float64'])

print(df_numeric.columns)
print(df_non_numeric.columns)
# Out:
# Index(['id', 'price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
#        'floors', 'sqft_above', 'yr_built', 'yr_renovated', 'zipcode', 'lat',
#        'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')
# Index(['date', 'waterfront', 'view', 'condition', 'grade', 'sqft_basement'], dtype='object')

# %%
# Converting grade values to numeric for easy data manipulation.
df['grade'] = df['grade'].str.slice(0,2).str.strip()
df['grade'] = df['grade'].astype(np.int64)

# %%
# Dealing missing values in views by converting them to numeric values.
df['view'].fillna('NONE', inplace=True)
df['view'].replace('NONE', '0', inplace=True)
df['view'].replace('FAIR', '1', inplace=True)
df['view'].replace('AVERAGE', '2', inplace=True)
df['view'].replace('GOOD', '3', inplace=True)
df['view'].replace('EXCELLENT', '4', inplace=True)
df['view'] = df['view'].astype(np.int64)

# %%
# Converting yr_renovated values to numeric int for easy data manipulation.
# 0 means the house is not renovated and 1 means the house is renovated.
df['yr_renovated'] = df['yr_renovated'].fillna(0)
df['is_rennovated'] = df['yr_renovated'].map(lambda x: 1 if x > 0 else 0)
df['is_rennovated'].value_counts()
df = df.drop(['yr_renovated'], axis=1)
df.is_rennovated.value_counts()
# Out:
# 0    20853
# 1      744
# Name: is_rennovated, dtype: int64

# %%
# Dropping the ID and Date columns since we will not use them for our analysis
df.drop(['id','date', 'waterfront'],axis=1,inplace=True)
df.reset_index(drop=True,inplace=True)

# %%
# Using the Q3 statistic (645,000)
# When I used an arbitrary price 1,000,000, not enough data samples, only 1490 total houses. Jelly requires 5,000
#luxury_homes_overQ3 = df.loc[df['price'] >= 645000]
#luxury_homes_overQ3

# %%
#There are 5411 homes with the price over or equal to the Q3 statistic (75th percentile).

# %%
#luxury_homes_overQ3['price']

# %%
sns.displot(df['price'])

# %%
import folium
# Dividing the entire King County up into sections Suburb, Rural, and Urban.
df_show = df.copy(deep=True)
lat = 47.5
long = -122.15

# Folium map initialization
my_map = folium.Map([lat, long], zoom_start=9)

urban = [
    # Starting point at Bottom Left of Seattle
    [47.503347, -122.255819],
    [47.734022, -122.255819],
    [47.734022, -122.419374],
    [47.503347, -122.419374],
    [47.503347, -122.255819]
]

suburbs = [
    # Starting point at Top Left of Seattle area
    [47.734022, -122.419374],
    [47.777799, -122.419374],
    [47.777799, -121.998473],
    [47.362637, -122.003149],
    [47.288093, -122.177545],
    [47.257529, -122.249917],
    [47.257529, -122.419374],
    [47.503347, -122.419374],
]

rural = [
    [47.503347, -122.419374],
    [47.503347, -122.533756],
    [47.324233, -122.533756],
    [47.324233, -122.419374],
    [47.257529, -122.419374],
    [47.257529, -122.249917],
    [47.161605, -121.924595],
    [47.161605, -121.404507],
    [47.373455, -121.404507],
    [47.600453, -121.131500],
    [47.777799, -121.131500],
    [47.777799, -121.998473],
]

# Plot lines using coordinates
my_PolyLine=folium.PolyLine(locations=rural,weight=7, color = 'yellow')
my_map.add_child(my_PolyLine)
my_PolyLine=folium.PolyLine(locations=suburbs,weight=5, color = 'blue')
my_map.add_child(my_PolyLine)
my_PolyLine=folium.PolyLine(locations=urban,weight=3, color = 'green')
my_map.add_child(my_PolyLine)
# Adding all the point from the file to the map object using FastMarkerCluster
my_map.add_child(FastMarkerCluster(df_show[['lat', 'long']].values.tolist()))

my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# The folium map represents our three King County sections.
# The green depicts urban areas, blue represents suburban areas, and finally yellow represents the rural areas.

# %%
df['sqft_living'].mean()
# Out:
# 2080.3218502569803

# %%
zipcodes = {
    98001:'Suburbs', 98002:'Suburbs', 98003:'Suburbs', 98004:'Suburbs', 98005:'Suburbs',
    98006:'Suburbs', 98007:'Suburbs',98008:'Suburbs', 98010:'Rural', 98011:'Suburbs', 
    98014:'Rural', 98019:'Rural', 98022:'Rural', 98023:'Suburbs', 98024:'Rural', 
    98027:'Rural', 98028:'Suburbs', 98029:'Suburbs', 98030:'Suburbs', 98031:'Suburbs',
    98032:'Urban', 98033:'Suburbs', 98034:'Suburbs', 98038:'Rural', 98039:'Suburbs',
    98040:'Urban', 98042:'Rural', 98045:'Rural', 98052:'Suburbs', 98053:'Rural',
    98055:'Urban', 98056:'Suburbs', 98058:'Suburbs', 98059:'Suburbs', 98065:'Rural',
    98070:'Urban', 98072:'Suburbs', 98074:'Suburbs', 98075:'Suburbs', 98077:'Rural',
    98092:'Urban', 98102:'Urban', 98103:'Urban', 98105:'Urban', 98106:'Urban',
    98107:'Urban', 98108:'Urban', 98109:'Urban', 98112:'Urban', 98115:'Urban', 
    98116:'Urban', 98117:'Urban', 98118:'Urban', 98119:'Urban', 98122:'Urban',
    98125:'Urban', 98126:'Urban', 98133:'Urban', 98136:'Urban', 98144:'Urban', 
    98146:'Urban', 98148:'Urban', 98155:'Urban', 98166:'Urban', 98168:'Urban',
    98177:'Urban', 98178:'Urban', 98188:'Urban', 98198:'Urban', 98199:'Urban'
    }

df['areas'] = df['zipcode'].map(zipcodes)
df.drop('zipcode', axis=1, inplace=True);

# %%
condition_map = {
                 'Poor': 0,
                 'Fair': 1,
                 'Average': 2,
                 'Good': 3,
                 'Very Good': 4
                }

df['conditions'] = df['condition'].map(condition_map)
df.drop('condition', axis = 1, inplace=True);

# %% [markdown]
# ## Training and Modeling

# %%
# Training our data.
X_train, X_test, y_train, y_test = train_test_split(df.drop('price', axis=1), df['price'], test_size=0.33, random_state=42)

# %%
X_train.head()
# Out:
#        bedrooms  bathrooms  sqft_living  sqft_lot  floors  view  grade  \
# 19709         5       3.75         3330      5042     2.0     2      9
# 4800          3       2.00         1678     13862     1.0     0      7
# 13225         4       1.00         1550     15239     1.5     4      6
# 16111         3       2.50         2760      9471     1.0     2      8
# 17711         2       1.50         1400      5810     2.0     0      7
#
#        sqft_above sqft_basement  yr_built      lat     long  sqft_living15  \
# 19709        2470         860.0      2014  47.6497 -122.339           1780
# 4800         1678           0.0      1994  47.3744 -122.190           1550
# 13225        1370         180.0      1930  47.4502 -122.378           1790
# 16111        1760        1000.0      1956  47.6760 -122.272           3040
# 17711        1400           0.0      1940  47.6843 -122.341           1470
#
#        sqft_lot15  is_rennovated    areas  conditions
# ...

# %%
# Creates scaled features dataframe and then adds on price column

# Train
X_train_scaled = pd.DataFrame(X_train)
X_train_scaled.columns = df.drop('price', axis=1).columns
y_train.reset_index(drop=True,inplace=True)
X_train_scaled_final = pd.concat((X_train_scaled,y_train),axis=1)
X_train.reset_index(drop=True,inplace=True)
X_train_final = pd.concat((X_train,y_train),axis=1)

# Test
X_test_scaled = pd.DataFrame(X_test)
X_test_scaled.columns = df.drop('price', axis=1).columns
y_test.reset_index(drop=True,inplace=True)
X_test_scaled_final = pd.concat((X_test_scaled,y_test),axis=1)

# %% [markdown]
# Setting up the baseline that we will use to compare linear regression models that we will be building in our model.

# %%
# Baseline Model - Average Price.
baseline_mean = X_train_scaled_final['price'].mean()
model_base = DummyRegressor(strategy='mean', constant=baseline_mean)
baseline_mean
# Out:
# 542085.8330223236

# %%
#formula = 'price ~ sqft_living + view + condition'
#model = ols(formula,X_train_scaled_final).fit()
#model.summary()

# %%
df_copy = df[['sqft_living', 'price', 'lat', 'long', 'sqft_lot', 'conditions', 'bedrooms', 'grade']]
df_copy.head()
# Out:
#    sqft_living     price      lat     long  sqft_lot  conditions  bedrooms  \
# 0         1180  221900.0  47.5112 -122.257      5650           2         3
# 1         2570  538000.0  47.7210 -122.319      7242           2         3
# 2          770  180000.0  47.7379 -122.233     10000           2         2
# 3         1960  604000.0  47.5208 -122.393      5000           4         4
# 4         1680  510000.0  47.6168 -122.045      8080           2         3
#
#    grade
# 0      7
# 1      7
# 2      6
# 3      7
# 4      8

# %%
x_ml = df_copy.drop(['price'], axis = 1).values
y_ml = df_copy['price'].values

# %%
x_train_ml, x_test_ml, y_train_ml, y_test_ml = train_test_split(x_ml, y_ml, test_size=0.33, random_state=42)

# %%
ml = LinearRegression()
ml.fit(x_train_ml, y_train_ml)
# Out:
# LinearRegression()

# %%
# Predicting our test set results
y_predict = ml.predict(x_test_ml)
print(y_predict)
# Out:
# [108905.26220962 426473.94476506 169254.1699339  ... 434383.74281514
#  526267.62292938 804427.14493896]

# %%
plt.figure(figsize = (12, 9))
plt.scatter(y_test_ml, y_predict)
plt.xlabel('House Qualities', size = 15)
plt.ylabel('House Price prediction', size = 15)
plt.title('Luxury House Price vs Sqft of Living Space', size = 15)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Evaluating our model using R2 Score
r2_score(y_test_ml, y_predict)
# Out:
# 0.6255195882341757

# %%
mean_sq_err = metrics.mean_squared_error(y_test_ml, y_predict)

# %%
RMSE = np.sqrt(mean_sq_err)
RMSE
# Out:
# 221265.76027353908

# %%
plt.figure(figsize = (15, 9))
ml_graph = sns.barplot(x=df['areas'], y=df['price'], order=['Suburbs','Urban','Rural'])
ylabels = ['0', '1M', '2M', '3M', '4M', '5M', '6M', '7M', '8M']
ml_graph.set_yticklabels(labels = ylabels)
plt.xlabel('Geographic Area', size = 15)
plt.ylabel('House Price ($ Millions)', size = 15)
plt.title('Average House Price vs Geographic Area', size = 15)
# Out:
# <ipython-input-40-573a63e7a253>:4: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ml_graph.set_yticklabels(labels = ylabels)
# Text(0.5, 1.0, 'Average House Price vs Geographic Area')
